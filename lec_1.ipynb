# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2*np.pi, 50)
plt.plot(x, np.sin(x))

# %%
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'>

# %%
x[0]
# Out:
# np.float64(0.0)

# %%
x[49]
# Out:
# np.float64(6.283185307179586)

# %%
x[49]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1904194664.py in <cell line: 0>()
# ----> 1 x[50]
#
# IndexError: index 50 is out of bounds for axis 0 with size 50

# %%
x[-1]
# Out:
# np.float64(6.283185307179586)

# %%
plt.plot(x, np.sin(x))
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.title('sinusoidal')
plt.legend(['sin(x)'], loc='upper right');

# %%
plt.plot(x, np.sin(x), 'b')
plt.plot(x, 0.5*np.sin(2*x), 'g', linewidth= 2)
plt.annotate('local maxima', xy = (1.5,1))
# Out:
# Text(1.5, 1, 'local maxima')

# %%
plt.savefig('sin.png')

# %%
plt.savefig('sin.pdf')
